# %% [markdown]
# # 🗺️ SpotMap — make an interactive map of India
#
# **No coding needed.** Just do this:
#
# 1. Click the **▶ play button** on the cell below (or press **Shift + Enter**).
# 2. Wait a few seconds, then click **Choose Files** and pick your data file (CSV or Excel).
# 3. Answer the short questions (press **Enter** to accept each suggestion).
#
# Your map appears right below, and is also saved as `spotmap.html` (in the **Files** panel on the left).
#
# _Your file needs a **latitude** column, a **longitude** column, and (optionally) a **case/control** column. Column names are detected automatically._
#
# ---
# _Made by ADARV._

# %%
# ▶ Click the play button on the left to start
# !pip install -q spotmap
from spotmap import spotmap_run
spotmap_run()
